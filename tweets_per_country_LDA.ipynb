# %% [markdown]
# ## Load the dataset using pandas

# %%
import pandas as pd
import numpy as np

# %%
file_name = 'brazil_df.csv'

# %%
df = pd.read_csv(file_name)
# Out:
# C:\Users\Kevvol\AppData\Local\Temp\ipykernel_4012\707990406.py:1: DtypeWarning: Columns (0) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv(file_name)

# %%
df
# Out:
#                     tweet_id            date_time lang       user_id  \
# 0        1333561484631273473  2020-12-01 00:00:08   pt  1.256964e+18
# 1        1333561534233001988  2020-12-01 00:00:20   pt  1.254859e+18
# 2        1333561535835332608  2020-12-01 00:00:21   pt  1.247532e+18
# 3        1333561544286867457  2020-12-01 00:00:23   pt  9.605948e+17
# 4        1333561579485470721  2020-12-01 00:00:31   pt  9.605948e+17
# ...                      ...                  ...  ...           ...
# 2233796  1377410322256916480  2021-03-31 23:59:46   pt  8.272665e+17
# 2233797  1377410325423685636  2021-03-31 23:59:47   pt  3.392868e+08
# 2233798  1377410332369461253  2021-03-31 23:59:48   pt  4.718284e+07
# 2233799  1377410332797231104  2021-03-31 23:59:49   pt  8.634409e+17
# 2233800  1377410334583967746  2021-03-31 23:59:49   pt  9.896876e+17
#
#          retweeted_id  quoted_id  in_reply_to_id  sentiment_conf  \
# 0                 NaN        NaN             NaN           0.765
# ...

# %%
# extract only portuguese language entries
df_pt = df.loc[df['lang'] == 'pt']
print(len(df_pt))
# Out:
# 2127643

# %%
df_pt
# Out:
#                     tweet_id            date_time lang       user_id  \
# 0        1333561484631273473  2020-12-01 00:00:08   pt  1.256964e+18
# 1        1333561534233001988  2020-12-01 00:00:20   pt  1.254859e+18
# 2        1333561535835332608  2020-12-01 00:00:21   pt  1.247532e+18
# 3        1333561544286867457  2020-12-01 00:00:23   pt  9.605948e+17
# 4        1333561579485470721  2020-12-01 00:00:31   pt  9.605948e+17
# ...                      ...                  ...  ...           ...
# 2233796  1377410322256916480  2021-03-31 23:59:46   pt  8.272665e+17
# 2233797  1377410325423685636  2021-03-31 23:59:47   pt  3.392868e+08
# 2233798  1377410332369461253  2021-03-31 23:59:48   pt  4.718284e+07
# 2233799  1377410332797231104  2021-03-31 23:59:49   pt  8.634409e+17
# 2233800  1377410334583967746  2021-03-31 23:59:49   pt  9.896876e+17
#
#          retweeted_id  quoted_id  in_reply_to_id  sentiment_conf  \
# 0                 NaN        NaN             NaN           0.765
# ...

# %% [markdown]
# ##### remove url and @mentions from tweet
# using regex \
# source: https://www.datasnips.com/59/remove-usernames-http-links-from-tweet-data/

# %%
import re

def remove_usernames_links(tweet):
    tweet = re.sub('@[^\s]+','',tweet)
    tweet = re.sub('http[^\s]+','',tweet)
    return tweet

# %%
df_pt['text'] = df_pt['text'].apply(remove_usernames_links)
# Out:
# C:\Users\Kevvol\AppData\Local\Temp\ipykernel_4012\39966674.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_pt['text'] = df_pt['text'].apply(remove_usernames_links)

# %% [markdown]
# ##### comparison

# %%
print('pre removal sample:')
print('--------------------------------------------------')
print(df[23:29]['text'])
print()

print('post removal sample:')
print('--------------------------------------------------')
print(df_pt[23:29]['text'])
# Out:
# pre removal sample:
# --------------------------------------------------
# 23    Brasil registra 5,6 milhões de pessoas recuper...
# 24    A eleição atrapalhava as medidas 😉 https://t.c...
# 25    João Pessoa não tem mais covid aparentemente h...
# 26    Tem que levar mesmo, uma par de gente irrespon...
# 27    https://t.co/yaYo0LOwv5 \n\nAnálise do @olacie...
# 28    Para os curiosos, não! Não é teste de gravidez...
# Name: text, dtype: object
#
# post removal sample:
# --------------------------------------------------
# 23    Brasil registra 5,6 milhões de pessoas recuper...
# 24                  A eleição atrapalhava as medidas 😉
# 25        João Pessoa não tem mais covid aparentemente
# 26    Tem que levar mesmo, uma par de gente irrespon...
# 27     \n\nAnálise do  sobre a situação da covid no ...
# 28    Para os curiosos, não! Não é teste de gravidez...
# Name: text, dtype: object

# %% [markdown]
# ## Perform LDA on data
#
# Code copied from:\
# https://towardsdatascience.com/nlp-with-lda-latent-dirichlet-allocation-and-text-clustering-to-improve-classification-97688c23d98 \
# https://towardsdatascience.com/topic-modeling-and-latent-dirichlet-allocation-in-python-9bf156893c24 \
# https://scikit-learn.org/stable/auto_examples/applications/plot_topics_extraction_with_nmf_lda.html

# %%
# Author: Olivier Grisel <olivier.grisel@ensta.org>
#         Lars Buitinck
#         Chyi-Kwei Yau <chyikwei.yau@gmail.com>
# License: BSD 3 clause

from time import time
import matplotlib.pyplot as plt

from sklearn.feature_extraction.text import TfidfVectorizer, CountVectorizer
from sklearn.decomposition import NMF, MiniBatchNMF, LatentDirichletAllocation
from sklearn.datasets import fetch_20newsgroups

# %%
n_features = 3000
n_components = 10
n_top_words = 20
batch_size = 128
init = "nndsvda"

# %% [markdown]
# ##### Utility function

# %%
def plot_top_words(model, feature_names, n_top_words, title):
    fig, axes = plt.subplots(2, 5, figsize=(30, 15), sharex=True)
    axes = axes.flatten()
    for topic_idx, topic in enumerate(model.components_):
        top_features_ind = topic.argsort()[: -n_top_words - 1 : -1]
        top_features = [feature_names[i] for i in top_features_ind]
        weights = topic[top_features_ind]

        ax = axes[topic_idx]
        ax.barh(top_features, weights, height=0.7)
        ax.set_title(f"Topic {topic_idx +1}", fontdict={"fontsize": 30})
        ax.invert_yaxis()
        ax.tick_params(axis="both", which="major", labelsize=20)
        for i in "top right left".split():
            ax.spines[i].set_visible(False)
        fig.suptitle(title, fontsize=40)

    plt.subplots_adjust(top=0.90, bottom=0.05, wspace=0.90, hspace=0.3)
    plt.show()

# %% [markdown]
# ##### loading a sample dataset
# this is just a vistege from copying the code from source

# %%
# Load the 20 newsgroups dataset and vectorize it. We use a few heuristics
# to filter out useless terms early on: the posts are stripped of headers,
# footers and quoted replies, and common English words, words occurring in
# only one document or in at least 95% of the documents are removed.

print("Loading dataset...")
t0 = time()
data, _ = fetch_20newsgroups(
    shuffle=True,
    random_state=1,
    remove=("headers", "footers", "quotes"),
    return_X_y=True,
)
data_samples = data[:n_samples]
print("done in %0.3fs." % (time() - t0))
# Out:
# Loading dataset...
# done in 121.224s.

# %%
len(data_samples[13])
# Out:
# 1028

# %% [markdown]
# ##### setup our dataset
# dataset of Brazilian tweets, note that here the code want just a python list of text strings

# %%
# use the df.to_list() function
df_pt[:5]["text"].to_list()
# Out:
# ['Dados atualizados no dia 01/12/2020 às 00:00 sobre o #coronavirus #COVID19 no Brasil:\n6,335,878 casos confirmados (21,138 novos casos)\n5,601,804 pacientes recuperados\n173,120 mortes confirmadas (272 novas mortes)',
#  'São registrados, no total, 173.165 mortes e 6.336.278 casos de #COVID19 no Brasil.',
#  'Atualização dos dados do Brasil. #coronavirus #covid19 ',
#  'A OMS pediu nesta segunda-feira ao Brasil que leve "muito a sério" os números crescentes de casos de coronavírus, uma tendência que o diretor-geral do órgão, Tedros Adhanom Ghebreyesus, descreveu como "muito, muito preocupante" ',
#  'Chefe da OMS diz que estado atual da epidemia no Brasil é "muito, muito preocupante" e que o país precisa agir para conter o aumento dos casos de covid-19. ']

# %%
data_samples = df_pt["text"].to_list()

# %%
n_samples = len(data_samples)

# %% [markdown]
# ##### feature extraction using TF-IDF
#
# instead of English stopwords, we need Portuguese stopwords\
# a list is found here: https://gist.github.com/alopes/5358189

# %%
pt_stopwords_file = open('pt_stopwords.txt')
pt_stopwords = pt_stopwords_file.readlines()
pt_stopwords = [w.strip() for w in pt_stopwords]
pt_stopwords_file.close()

print(pt_stopwords[:18])
# Out:
# ['de', 'a', 'o', 'que', 'e', 'do', 'da', 'em', 'um', 'para', 'Ã©', 'com', 'nÃ£o', 'uma', 'os', 'no', 'se', 'na']

# %%
# Use tf-idf features for NMF.
print("Extracting tf-idf features for NMF...")
tfidf_vectorizer = TfidfVectorizer(
    max_df=0.95, min_df=2, max_features=n_features, stop_words=pt_stopwords
)
t0 = time()
tfidf = tfidf_vectorizer.fit_transform(data_samples)
print("done in %0.3fs." % (time() - t0))
# Out:
# Extracting tf-idf features for NMF...
# C:\Users\Kevvol\AppData\Local\Programs\Python\Python310\lib\site-packages\sklearn\feature_extraction\text.py:404: UserWarning: Your stop_words may be inconsistent with your preprocessing. Tokenizing the stop words generated tokens ['amos', 'atã', 'estivã', 'estã', 'fã', 'houverã', 'houvã', 'hã', 'jã', 'nhamos', 'nã', 'nã³s', 'ramos', 'serã', 'ssemos', 'sã', 'sã³', 'tambã', 'terã', 'tivã', 'tã', 'tãªm', 'vamos', 'vocãª', 'vocãªs'] not in stop_words.
#   warnings.warn(
# done in 43.288s.

# %%
# Use tf (raw term count) features for LDA.
print("Extracting tf features for LDA...")
tf_vectorizer = CountVectorizer(
    max_df=0.95, min_df=2, max_features=n_features, stop_words=pt_stopwords
)
t0 = time()
tf = tf_vectorizer.fit_transform(data_samples)
print("done in %0.3fs." % (time() - t0))
print()
# Out:
# Extracting tf features for LDA...
# done in 41.694s.

# %% [markdown]
# ##### fit a model

# %%
# Fit the NMF model
print(
    "Fitting the NMF model (Frobenius norm) with tf-idf features, "
    "n_samples=%d and n_features=%d..." % (n_samples, n_features)
)
t0 = time()
nmf = NMF(
    n_components=n_components,
    random_state=1,
    init=init,
    beta_loss="frobenius",
    alpha_W=0.00005,
    alpha_H=0.00005,
    l1_ratio=1,
).fit(tfidf)
print("done in %0.3fs." % (time() - t0))


tfidf_feature_names = tfidf_vectorizer.get_feature_names_out()
plot_top_words(
    nmf, tfidf_feature_names, n_top_words, "Topics in NMF model (Frobenius norm)"
)

# Fit the NMF model
print(
    "\n" * 2,
    "Fitting the NMF model (generalized Kullback-Leibler "
    "divergence) with tf-idf features, n_samples=%d and n_features=%d..."
    % (n_samples, n_features),
)
t0 = time()
nmf = NMF(
    n_components=n_components,
    random_state=1,
    init=init,
    beta_loss="kullback-leibler",
    solver="mu",
    max_iter=1000,
    alpha_W=0.00005,
    alpha_H=0.00005,
    l1_ratio=0.5,
).fit(tfidf)
print("done in %0.3fs." % (time() - t0))

tfidf_feature_names = tfidf_vectorizer.get_feature_names_out()
plot_top_words(
    nmf,
    tfidf_feature_names,
    n_top_words,
    "Topics in NMF model (generalized Kullback-Leibler divergence)",
)
# Out:
# Fitting the NMF model (Frobenius norm) with tf-idf features, n_samples=2127643 and n_features=3000...
# done in 55.121s.
#  Fitting the NMF model (generalized Kullback-Leibler divergence) with tf-idf features, n_samples=2127643 and n_features=3000...
# done in 807.475s.

# %%
# Fit the MiniBatchNMF model
print(
    "\n" * 2,
    "Fitting the MiniBatchNMF model (Frobenius norm) with tf-idf "
    "features, n_samples=%d and n_features=%d, batch_size=%d..."
    % (n_samples, n_features, batch_size),
)
t0 = time()
mbnmf = MiniBatchNMF(
    n_components=n_components,
    random_state=1,
    batch_size=batch_size,
    init=init,
    beta_loss="frobenius",
    alpha_W=0.00005,
    alpha_H=0.00005,
    l1_ratio=0.5,
).fit(tfidf)
print("done in %0.3fs." % (time() - t0))


tfidf_feature_names = tfidf_vectorizer.get_feature_names_out()
plot_top_words(
    mbnmf,
    tfidf_feature_names,
    n_top_words,
    "Topics in MiniBatchNMF model (Frobenius norm)",
)

# Fit the MiniBatchNMF model
print(
    "\n" * 2,
    "Fitting the MiniBatchNMF model (generalized Kullback-Leibler "
    "divergence) with tf-idf features, n_samples=%d and n_features=%d, "
    "batch_size=%d..." % (n_samples, n_features, batch_size),
)
t0 = time()
mbnmf = MiniBatchNMF(
    n_components=n_components,
    random_state=1,
    batch_size=batch_size,
    init=init,
    beta_loss="kullback-leibler",
    alpha_W=0.00005,
    alpha_H=0.00005,
    l1_ratio=0.5,
).fit(tfidf)
print("done in %0.3fs." % (time() - t0))

tfidf_feature_names = tfidf_vectorizer.get_feature_names_out()
plot_top_words(
    mbnmf,
    tfidf_feature_names,
    n_top_words,
    "Topics in MiniBatchNMF model (generalized Kullback-Leibler divergence)",
)
# Out:
#  Fitting the MiniBatchNMF model (Frobenius norm) with tf-idf features, n_samples=2127643 and n_features=3000, batch_size=128...
# done in 20.309s.
#  Fitting the MiniBatchNMF model (generalized Kullback-Leibler divergence) with tf-idf features, n_samples=2127643 and n_features=3000, batch_size=128...
# done in 19.497s.

# %%
print(
    "\n" * 2,
    "Fitting LDA models with tf features, n_samples=%d and n_features=%d..."
    % (n_samples, n_features),
)
lda = LatentDirichletAllocation(
    n_components=n_components,
    max_iter=5,
    learning_method="online",
    learning_offset=50.0,
    random_state=0,
)
t0 = time()
lda.fit(tf)
print("done in %0.3fs." % (time() - t0))

tf_feature_names = tf_vectorizer.get_feature_names_out()
plot_top_words(lda, tf_feature_names, n_top_words, "Topics in LDA model")
# Out:
#  Fitting LDA models with tf features, n_samples=2127643 and n_features=3000...
# done in 1030.048s.

# %%
tf_feature_names
# Out:
# array(['00', '000', '01', ..., 'últimos', 'única', 'único'], dtype=object)

# %%
print(np.where(tf_feature_names == 'máscara'))     # mask
print(np.where(tf_feature_names == 'cama'))        # bed
print(np.where(tf_feature_names == 'oxigênio'))    # oxygen
# Out:
# (array([1893], dtype=int64),)
# (array([], dtype=int64),)
# (array([2027], dtype=int64),)

# %%
def get_top_words_list(model, feature_names, n_top_words):
    res = []
    
    for topic_idx, topic in enumerate(model.components_):
        top_features_ind = topic.argsort()[: -n_top_words - 1 : -1]
        top_features = [feature_names[i] for i in top_features_ind]
        weights = topic[top_features_ind]
        
        frame = pd.DataFrame(data={'word': top_features, 'weight': weights})
        res.append(frame)
    
    return res

# %%
top_words = get_top_words_list(lda, tf_feature_names, 50)

# %%
top_words
# Out:
# [           word         weight
#  0        brasil  159395.600423
#  1    tratamento   89303.997635
#  2          novo   88869.892656
#  3       precoce   84450.257059
#  4       covid19   80520.983002
#  5      pandemia   76369.921035
#  6       estados   74482.356587
#  7        países   67546.091885
#  8          2020   66801.858638
#  9           ano   63507.323213
#  10       rússia   59964.291800
#  11       méxico   58680.108238
#  12          dia   57109.681084
#  13       também   56544.245179
#  14          eua   55801.186682
#  15         país   51570.913025
#  16  coronavírus   49241.961117
#  17        índia   48879.678020
#  18        maior   46004.632913
#  19       mortes   45739.989418
#  20        sendo   45157.720419
#  21      polônia   43886.703797
#  22          563   42020.630727
#  23     alemanha   41466.348052
#  24       frança   41123.463299
#  25           11   41048.198320
#  26           já   40510.269706
#  27           03   39952.818162
# ...

# %%
def create_lda_model(tf, n_components):
    print(
        "\n" * 2,
        "Fitting LDA models with tf features, n_samples=%d and n_features=%d..."
        % (n_samples, n_features),
    )
    lda = LatentDirichletAllocation(
        n_components=n_components,
        max_iter=5,
        learning_method="online",
        learning_offset=50.0,
        random_state=0,
    )
    t0 = time()
    lda.fit(tf)
    print("n_components = %d case done in %0.3fs." % (n_components, time() - t0))
    return lda

# %%
lda_models = {}

for j in range(5, 30):
    model = create_lda_model(tf, j)
    lda_models[j] = model
# Out:
#  Fitting LDA models with tf features, n_samples=2127643 and n_features=3000...
# n_components = 5 case done in 1189.121s.
#
#
#  Fitting LDA models with tf features, n_samples=2127643 and n_features=3000...
# n_components = 6 case done in 1106.316s.
#
#
#  Fitting LDA models with tf features, n_samples=2127643 and n_features=3000...
# n_components = 7 case done in 1064.180s.
#
#
#  Fitting LDA models with tf features, n_samples=2127643 and n_features=3000...
# n_components = 8 case done in 1063.525s.
#
#
#  Fitting LDA models with tf features, n_samples=2127643 and n_features=3000...
# n_components = 9 case done in 1056.696s.
#
#
#  Fitting LDA models with tf features, n_samples=2127643 and n_features=3000...
# n_components = 10 case done in 1025.797s.
#
#
#  Fitting LDA models with tf features, n_samples=2127643 and n_features=3000...
# n_components = 11 case done in 1075.212s.
#
#
#  Fitting LDA models with tf features, n_samples=2127643 and n_features=3000...
# ...

# %%
lda_models
# Out:
# {5: LatentDirichletAllocation(learning_method='online', learning_offset=50.0,
#                            max_iter=5, n_components=5, random_state=0),
#  6: LatentDirichletAllocation(learning_method='online', learning_offset=50.0,
#                            max_iter=5, n_components=6, random_state=0),
#  7: LatentDirichletAllocation(learning_method='online', learning_offset=50.0,
#                            max_iter=5, n_components=7, random_state=0),
#  8: LatentDirichletAllocation(learning_method='online', learning_offset=50.0,
#                            max_iter=5, n_components=8, random_state=0),
#  9: LatentDirichletAllocation(learning_method='online', learning_offset=50.0,
#                            max_iter=5, n_components=9, random_state=0),
#  10: LatentDirichletAllocation(learning_method='online', learning_offset=50.0,
#                            max_iter=5, random_state=0),
#  11: LatentDirichletAllocation(learning_method='online', learning_offset=50.0,
# ...

# %%
import pickle

pickle.dump( lda_models, open( "lda_models_5-29_3000_features.p", "wb" ) )

# %%
tf_sets = {'tf_vector': tf, 'tf_vectorizer': tf_vectorizer}

pickle.dump( tf_sets, open( "lda_models_5-29_3000_features_tf_source.p", "wb" ) )
